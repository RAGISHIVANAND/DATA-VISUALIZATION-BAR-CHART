# %% [markdown]
# <a href="https://colab.research.google.com/github/RAGISHIVANAND/DATA-VISUALIZATION-BAR-CHART/blob/main/Bar_chart_python_notebook2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_used_cars = pd.read_csv("/content/drive/MyDrive/bar_chart_data.csv")

# %%
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize = (9,6))
plt.bar(x = df_used_cars["Brand"],
        height = df_used_cars["Cars Listings"])
plt.xticks(rotation = 45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
